# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
data = pd.read_csv('600708_1.csv',  index_col=0, encoding='gb2312')
#data['收盘价'].plot(grid=True, figsize=(15,8))

# %%
data1=data.sort_index()

# %%
data2=data1[data1['收盘价']>0]

# %%
data2['收盘价'].plot(grid=True, figsize=(15,8))

# %%
SD=0.3

# %%
data2['42d']=pd.rolling_mean(data2['收盘价'],window=42)
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=42).mean()
#   if __name__ == '__main__':
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data2['252d']=pd.rolling_mean(data2['收盘价'],window=252)
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=252).mean()
#   if __name__ == '__main__':
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data2.tail(10)
# Out:
#                股票代码    名称   收盘价   最高价   最低价   开盘价   前收盘    涨跌额      涨跌幅  \
# 日期
# 2018-01-17  '600708  光明地产  7.70  8.03  7.68  8.00  7.99  -0.29  -3.6295
# 2018-01-18  '600708  光明地产  8.24  8.44  7.70  7.72  7.70   0.54    7.013
# 2018-01-19  '600708  光明地产  8.20  8.35  8.03  8.17  8.24  -0.04  -0.4854
# 2018-01-22  '600708  光明地产  8.78  8.91  8.14  8.18  8.20   0.58   7.0732
# 2018-01-23  '600708  光明地产  8.85  9.13  8.56  8.61  8.78   0.07   0.7973
# 2018-01-24  '600708  光明地产  8.91  9.00  8.59  8.73  8.85   0.06    0.678
# 2018-01-25  '600708  光明地产  8.42  8.93  8.30  8.93  8.91  -0.49  -5.4994
# 2018-01-26  '600708  光明地产  8.16  8.36  8.06  8.36  8.42  -0.26  -3.0879
# 2018-01-29  '600708  光明地产  8.18  8.30  8.12  8.14  8.16   0.02   0.2451
# 2018-01-30  '600708  光明地产  8.26  8.47  8.15  8.18  8.18   0.08    0.978
#
#                换手率       成交量         成交金额           总市值          流通市值  \
# 日期
# 2018-01-17  2.5220  24940154  194966746.0  1.320039e+10  7.614455e+09
# ...

# %%
data2[['收盘价', '42d', '252d']].plot(grid=True, figsize=(15,8))

# %%
data2['42-252']=data2['42d']-data2['252d']
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data2
# Out:
#                股票代码    名称    收盘价    最高价    最低价    开盘价    前收盘    涨跌额       涨跌幅  \
# 日期
# 1996-06-06  '600708  东海股份  16.87  18.00  16.80  17.49   5.80  11.07  190.8621
# 1996-06-07  '600708  东海股份  16.10  17.20  16.00  16.97  16.87  -0.77   -4.5643
# 1996-06-10  '600708  东海股份  14.85  16.33  14.56  16.20  16.10  -1.25    -7.764
# 1996-06-11  '600708  东海股份  14.85  15.48  14.63  14.68  14.85    0.0       0.0
# 1996-06-12  '600708  东海股份  14.55  15.13  14.51  15.05  14.85   -0.3   -2.0202
# 1996-06-13  '600708  东海股份  14.60  14.88  14.40  14.60  14.55   0.05    0.3436
# 1996-06-14  '600708  东海股份  14.08  15.10  13.89  14.80  14.60  -0.52   -3.5616
# 1996-06-17  '600708  东海股份  14.55  15.08  14.28  14.28  14.08   0.47    3.3381
# 1996-06-18  '600708  东海股份  15.30  15.65  14.38  14.50  14.55   0.75    5.1546
# 1996-06-19  '600708  东海股份  14.85  15.62  14.00  15.59  15.30  -0.45   -2.9412
# 1996-06-20  '600708  东海股份  15.18  15.38  14.68  14.79  14.85   0.33    2.2222
# ...

# %%
data2.tail()
# Out:
#                股票代码    名称   收盘价   最高价   最低价   开盘价   前收盘    涨跌额      涨跌幅  \
# 日期
# 2018-01-24  '600708  光明地产  8.91  9.00  8.59  8.73  8.85   0.06    0.678
# 2018-01-25  '600708  光明地产  8.42  8.93  8.30  8.93  8.91  -0.49  -5.4994
# 2018-01-26  '600708  光明地产  8.16  8.36  8.06  8.36  8.42  -0.26  -3.0879
# 2018-01-29  '600708  光明地产  8.18  8.30  8.12  8.14  8.16   0.02   0.2451
# 2018-01-30  '600708  光明地产  8.26  8.47  8.15  8.18  8.18   0.08    0.978
#
#                换手率       成交量         成交金额           总市值          流通市值  \
# 日期
# 2018-01-24  3.1261  30914056  271550757.0  1.527473e+10  8.811012e+09
# 2018-01-25  6.9909  69131918  587314234.0  1.443471e+10  8.326456e+09
# 2018-01-26  4.7287  46761698  383297733.0  1.398898e+10  8.069345e+09
# 2018-01-29  2.6540  26245166  215542444.0  1.402327e+10  8.089123e+09
# 2018-01-30  3.2699  32335232  270134401.0  1.416041e+10  8.168234e+09
#
#                  42d      252d    42-252
# 日期
# 2018-01-24  7.281429  7.916230 -0.634802
# ...
