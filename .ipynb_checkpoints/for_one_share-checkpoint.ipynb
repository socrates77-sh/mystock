# %%
# %matplotlib inline
from one_share import *

# %% [markdown]
# ### 输入股票代码

# %%
code = '002253'

# %%
stock_data = stock_data_reader(code)
analysis_data = calculat_average(stock_data)
strategy_data = average_strategy(analysis_data)

# %%
if(strategy_data['前复权'].count() < 500):
     print('%06s is a new share without enough data' % code)

# %%
gain_result = get_all_gain(strategy_data)

# %% [markdown]
# ### 最新报价

# %%
print('%s\t%06s\t%6s\t%0.2f' % (stock_data.index[-1], code, stock_data['名称'][-1], stock_data['收盘价'][-1]))
# Out:
# 2018-02-06	002253	  川大智胜	14.83

# %% [markdown]
# ### 各种策略250d/500d/all收益分析

# %%
plt.figure(figsize=(15,5))
ax = plt.subplot(121)
gain_result[['500d', '250d']].plot(kind='barh', ax=ax)
ax = plt.subplot(122)
gain_result['all'].plot(kind='barh', ax=ax, legend=True)

# %% [markdown]
# ### 各种策略250d/500d/all持仓时间比

# %%
plt.figure(figsize=(15,5))
ax = plt.subplot(131)
get_position_days(strategy_data, 250).plot(kind='barh', ax=ax, title='250d', stacked=True)
ax = plt.subplot(132)
get_position_days(strategy_data, 500).plot(kind='barh', ax=ax, title='500d', stacked=True)
ax = plt.subplot(133)
get_position_days(strategy_data, 0).plot(kind='barh', ax=ax, title='all', stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-a4977e020d44> in <module>()
#       1 plt.figure(figsize=(15,5))
#       2 ax = plt.subplot(131)
# ----> 3 get_position_days(strategy_data, 250).plot(kind='barh', ax=ax, title='250d', stacked=True)
#       4 ax = plt.subplot(132)
#       5 get_position_days(strategy_data, 500).plot(kind='barh', ax=ax, title='500d', stacked=True)
#
# E:\py\mystock\one_share.py in get_position_days(strategy_data, days)
#      15             pos_days['S'][ast] = strategy_data[ast].value_counts(1)[0]
#      16         else:
# ---> 17             pos_days['B'][ast] = strategy_data[ast][-days:].value_counts(1)[1]
#      18             pos_days['S'][ast] = strategy_data[ast][-days:].value_counts(1)[0]
#      19     return pos_days
#
# e:\python34\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
# ...

# %% [markdown]
# ### 月走势

# %%
analysis_data[['前复权', 'week', 'month', 'quarter', 'half-year', 'year']][-20:].plot(figsize=(15,8), grid=True)

# %% [markdown]
# ### 季度走势

# %%
analysis_data[['前复权', 'week', 'month', 'quarter', 'half-year', 'year']][-60:].plot(figsize=(15,8), grid=True)

# %% [markdown]
# ### 半年走势

# %%
analysis_data[['前复权', 'week', 'month', 'quarter', 'half-year', 'year']][-120:].plot(figsize=(15,8), grid=True)

# %% [markdown]
# ## 年走势

# %%
analysis_data[['前复权', 'week', 'month', 'quarter', 'half-year', 'year']][-250:].plot(figsize=(15,8), grid=True)

# %% [markdown]
# ### 历史走势

# %%
analysis_data[['前复权', 'week', 'month', 'quarter', 'half-year', 'year']].plot(figsize=(15,8), grid=True)
